# %% [markdown]
# # 7.2 조인

# %% [markdown]
# 두 개 이상의 테이블을 서로 묶어서 하나의 결과 집합으로 만들어 내는 것

# %% [markdown]
# ## 7.2.1 INNER JOIN

# %% [markdown]
# 대개의 업무에서 join이라고 얘기하는 것은 inner join을 지칭하는 것

# %% [markdown]
# 물건을 구매한 사용자의 아이디와 물건등의 정보만 있는데 회원의 주소도 필요함
# 이때 구매 테이블과 회원 테이블을 조인함

# %% [markdown]
# `SELECT <열>
#  FROM <첫 번째 테이블>
#      INNER JOIN<두 번째 테이블>
#      ON <조인될 조건>
#  WHERE 검색 조건`

# %% [markdown]
# jyp라는 아이디를 가진 사람이 구매한 물건을 발송하기 위해 조인한 결과

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 전체에 대한 결과

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 필요한 열만 추출

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 별칭을 사용하는 것을 권장

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 전체 회원들이 구매한 목록

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 결과는 전체 회원이 아니라 구매한 기록이 있는 회원들의 결과가 나왔는데 안 나온 사람들까지 나오게 하려면 OUTER JOIN을 해야함

# %% [markdown]
# INNER JOIN은 양쪽 테이블에 있는 내용만

# %% [markdown]
# DISTINCT,EXISTS도 가능

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - 실습4
# 3개의 테이블 조인

# %% [markdown]
# 테이블 생성하고 데이터 입력

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 학생,동아리,학생동아리 테이블을 이용해서 학생을 기준으로 이름/지역/동아리/방을 출력

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 동아리 기준

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 7.2.2 OUTER JOIN

# %% [markdown]
# `SELECT <열>
#  FROM <첫 번째 테이블(Left)>
#      <LEFT| RIHT|FULL>OUTER JOIN<두 번째 테이블(RIGHT)>
#      ON <조인될 조건>
#  WHERE 검색 조건`

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 왼쪽 테이블의 것은 모두 출력

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 구매한 적이 없는 유령 회원들

# %% [markdown]
# - 실습5

# %% [markdown]
# LEFT/RIGHT/FULL 실습

# %% [markdown]
# 실습4에서 동아리에 가입하지 않은 학생들은 출력이 되지 않았는데 outer join으로 출력하기

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 동아리 기준으로 가입된 학생을 출력하되, 가입 학생이 하나도 없는 동아리도 출력

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 위 결과 하나로 합치기

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 7.2.3 CROSS JOIN
