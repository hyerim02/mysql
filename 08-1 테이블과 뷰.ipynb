# %% [markdown]
# # 8.1 테이블

# %% [markdown]
# ## 8.1.1 테이블 만들기

# %% [markdown]
# 테이블을 어떻게 모델링 했는지가 훨씬 중요함

# %% [markdown]
# - 실습1

# %% [markdown]
# Navigator에서 테이블을 생성하고, 데이터를 입력

# %% [markdown]
# 우선 앞에 실습한 내용들 다 삭제

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 새로 만들기

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# usertbl에 없는 사람은 buytbl에 넣어서 생긴 오류

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - 실습2

# %% [markdown]
# SQL사용

# %% [markdown]
# 기본키,외래키 이런거 고려하지 않고 기본적인 틀만 구성

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 기본키 설정

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 순번열에 AUTO_INCREMENT설정

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 외래키 설정

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 데이터 입력

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 추가 입력

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 8.1.2 제약 조건

# %% [markdown]
# 데이터의 무결성을 지키기 위한 제한된 조건

# %% [markdown]
# - PRIMARY KEY
# - FOREIGN KEY
# - UNIQUE
# - CHECK
# - DEFAULT
# - NULL값 허용

# %% [markdown]
# ### PRIMARY KEY

# %% [markdown]
# 테이블에 존재하는 많은 행의 데이터를 구분할 수 있는 식별자를 기본 키(PRIMARY KEY )라고 부름
# 중복,NULL은 입력될 수 없음

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# `DESCRIBE usertbl;` 테이블의 정보를 알 수 있음

# %% [markdown]
# 키의 이름도 직접 지어줄 수 있음

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# PK가 userTBL테이블의 userID열에 지정됨을 읽을 수 있음

# %% [markdown]
# CONSTRAINT는 생략 가능 마지막에 PRIMARY KEY(userID)만 적으면 됨

# %% [markdown]
# 이미 테이블을 만들고 테이블 수정

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# A+B를 합쳐야 하는 경우

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 테이블 확인

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ###  FOREIGN KEY

# %% [markdown]
# 두 테이블 사이의 관계를 선언함으로써 데이터의 무결성을 보장해 주는 역할
# 외래 키를 설정하면 하나의 테이블이 다른 테이블에 의존함

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 외래 키 이름을 지정

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ALTER TABLE구문 사용

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - ALTER TABLE buytbl: buytbl을 수정한다

# %% [markdown]
# - ADD CONSTRAINT FK_usertbl_buytbl: 제약 조건을 더한다

# %% [markdown]
# - FOREIGN KEY (userID): 외래 키 제약 조건을 buytbl의 userID에 설정

# %% [markdown]
# - REFERENCES userTBL(userID): 참조할 기준 테이블은 usertbl 테이블의 userID열

# %% [markdown]
# 기준 테이블의 데이터가 변경되었을 때 외래 키 테이블도 자동을로 적용되도록 설정

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 예를 들면 회원 테이블의 김범수의 ID인 KBS가 kim으로 변결될 경우에 구매 테이블도 변경이 됨

# %% [markdown]
# 별도로 지정하지 않으면 ON UPDATE NO ACTION 및  ON DELETE NO ACTION을 지정한 것과 동일
# 즉 회원 테이블의 회원 아이디가 변경이 되어도 아무런 일이 일어나지 않음

# %% [markdown]
# ### UNIQUE

# %% [markdown]
# 중복되지 않는 유일한 값을 입력해야 하는 조건

# %% [markdown]
# NULL값 허용

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### CHECK

# %% [markdown]
# 입력되는 데이터를 점검하는 기능
# 키에 마이너스 값이 들어올 수 없게 하든지 등등

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 열 정의 하고 바로 예약어오 조건을 지정
# 두번째는 열을 모두 정의하고 마지막에 추가, 제약 이름을 직접 지정 가능

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 필요하면 열을 정의한 후 ALTER TABLE문으로 제약 조건을 추가해도 된다

# %% [markdown]
# ### DEFAULT

# %% [markdown]
# 값을 입력하지 않았을 때 자동으로 입력되는 기본 값을 정의하는 방법

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
