# %% [markdown]
# - 범위가 있는 경우 인덱스 없는 테이블 조회

# %%
import pandas as pd
import pymysql

# %%
conn1=pymysql.connect(host='127.0.0.1',user='root',password='1234',db='indexdb',charset='utf8')

# %%
cur_1=conn1.cursor()

# %%
sql="SHOW GLOBAL STATUS LIKE 'Innodb_pages_read';"

# %%
cur_1.execute(sql)
rows_1=cur_1.fetchall()
conn1.close()

# %%
pd_1=pd.DataFrame(rows_1)
pd_1
# Out:
#                    0     1
# 0  Innodb_pages_read  1053

# %%
import pandas as pd
import pymysql

# %%
conn1=pymysql.connect(host='127.0.0.1',user='root',password='1234',db='indexdb',charset='utf8')

# %%
cur_1=conn1.cursor()

# %%
sql="SHOW GLOBAL STATUS LIKE 'Innodb_pages_read';"

# %%
cur_1.execute(sql)
rows_1=cur_1.fetchall()
conn1.close()

# %%
pd_1=pd.DataFrame(rows_1)
pd_1
# Out:
#                    0     1
# 0  Innodb_pages_read  1535

# %% [markdown]
# - 클러스터형 인덱스 테이블

# %%
import pandas as pd
import pymysql

# %%
conn1=pymysql.connect(host='127.0.0.1',user='root',password='1234',db='indexdb',charset='utf8')

# %%
cur_1=conn1.cursor()

# %%
sql="SHOW GLOBAL STATUS LIKE 'Innodb_pages_read';"

# %%
cur_1.execute(sql)
rows_1=cur_1.fetchall()
conn1.close()

# %%
pd_1=pd.DataFrame(rows_1)
pd_1
# Out:
#                    0     1
# 0  Innodb_pages_read  1047

# %%
import pandas as pd
import pymysql

# %%
conn1=pymysql.connect(host='127.0.0.1',user='root',password='1234',db='indexdb',charset='utf8')

# %%
cur_1=conn1.cursor()

# %%
sql="SHOW GLOBAL STATUS LIKE 'Innodb_pages_read';"

# %%
cur_1.execute(sql)
rows_1=cur_1.fetchall()
conn1.close()

# %%
pd_1=pd.DataFrame(rows_1)
pd_1
# Out:
#                    0     1
# 0  Innodb_pages_read  1052

# %% [markdown]
# - 클러스터형 인덱스에서 전체 데이터를 읽어보기

# %%
import pandas as pd
import pymysql

# %%
conn1=pymysql.connect(host='127.0.0.1',user='root',password='1234',db='indexdb',charset='utf8')

# %%
cur_1=conn1.cursor()

# %%
sql="SHOW GLOBAL STATUS LIKE 'Innodb_pages_read';"

# %%
cur_1.execute(sql)
rows_1=cur_1.fetchall()
conn1.close()

# %%
pd_1=pd.DataFrame(rows_1)
pd_1
# Out:
#                    0     1
# 0  Innodb_pages_read  1046

# %%
import pandas as pd
import pymysql

# %%
conn1=pymysql.connect(host='127.0.0.1',user='root',password='1234',db='indexdb',charset='utf8')

# %%
cur_1=conn1.cursor()

# %%
sql="SHOW GLOBAL STATUS LIKE 'Innodb_pages_read';"

# %%
cur_1.execute(sql)
rows_1=cur_1.fetchall()
conn1.close()

# %%
pd_1=pd.DataFrame(rows_1)
pd_1
# Out:
#                    0     1
# 0  Innodb_pages_read  1934

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 클러스터형 인덱스의 전체 범위를 읽은 것으로 생각하면 됨

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 19M를 읽었다는 것을 알 수 있는데 전체 데이터를 읽어야해서 많이 읽을 수 밖에 없음

# %% [markdown]
# - 인덱스 힌트를 사용하지 못하게 막음

# %%
import pandas as pd
import pymysql

# %%
conn1=pymysql.connect(host='127.0.0.1',user='root',password='1234',db='indexdb',charset='utf8')

# %%
cur_1=conn1.cursor()

# %%
sql="SHOW GLOBAL STATUS LIKE 'Innodb_pages_read';"

# %%
cur_1.execute(sql)
rows_1=cur_1.fetchall()
conn1.close()

# %%
pd_1=pd.DataFrame(rows_1)
pd_1
# Out:
#                    0     1
# 0  Innodb_pages_read  1048

# %%
import pandas as pd
import pymysql

# %%
conn1=pymysql.connect(host='127.0.0.1',user='root',password='1234',db='indexdb',charset='utf8')

# %%
cur_1=conn1.cursor()

# %%
sql="SHOW GLOBAL STATUS LIKE 'Innodb_pages_read';"

# %%
cur_1.execute(sql)
rows_1=cur_1.fetchall()
conn1.close()

# %%
pd_1=pd.DataFrame(rows_1)
pd_1
# Out:
#                    0     1
# 0  Innodb_pages_read  1936

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 인덱스가 없어서 전체 테이블을 검색했으며 19M보다 적은 12M만큼 읽음
# 전체 데이터를 읽을 때는 인덱스를 사용하지 않는 것이 더 효율적

# %% [markdown]
# - where 조건이 없는 전체 데이터 조회

# %%
import pandas as pd
import pymysql

# %%
conn1=pymysql.connect(host='127.0.0.1',user='root',password='1234',db='indexdb',charset='utf8')

# %%
cur_1=conn1.cursor()

# %%
sql="SHOW GLOBAL STATUS LIKE 'Innodb_pages_read';"

# %%
cur_1.execute(sql)
rows_1=cur_1.fetchall()
conn1.close()

# %%
pd_1=pd.DataFrame(rows_1)
pd_1
# Out:
#                    0     1
# 0  Innodb_pages_read  1048

# %%
import pandas as pd
import pymysql

# %%
conn1=pymysql.connect(host='127.0.0.1',user='root',password='1234',db='indexdb',charset='utf8')

# %%
cur_1=conn1.cursor()

# %%
sql="SHOW GLOBAL STATUS LIKE 'Innodb_pages_read';"

# %%
cur_1.execute(sql)
rows_1=cur_1.fetchall()
conn1.close()

# %%
pd_1=pd.DataFrame(rows_1)
pd_1
# Out:
#                    0     1
# 0  Innodb_pages_read  1936

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 전체 데이터에 접근해야 하므로 인덱스를 검색하지 않고 전체 테이블을 검색함
