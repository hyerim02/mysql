# %% [markdown]
# # chapter01 DBMS개요와 MySQL 소개
# ---

# %% [markdown]
# ## 1.1 DBMS개요
# ---

# %% [markdown]
# ### 1.1.1데이터베이스의 정의와 특징
# ---

# %% [markdown]
# `데이터베이스 : 데이터의 집합`이라고 정의하면 `DBMS`는 이 데이터베이스를 관리,운영하는 역할을 하는 소프트웨어
# 데이터베이스는 여러 명의 사용자나 응용 프로그램이 공유하고 동시에 접근이 가능해야 함
# 엑셀은 여러 명의 사용자가 공유하는 개념이 아니라서 DBMS라고 부르지 않음
# `데이터베이스 : 데이터의 저장공간`자체를 의미하기도 함
# MySQL에서는 데이터베이스를 자료가 저장되는 디스크 공간(파일)으로 취급

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - MySQL 외에도 많이 사용되는 DBMS
#
# |DBMS|제작사|운영체제|최신버전(2020년 초 기준)|기타|
# |---|---|------|---|---|
# |MySQL|Oracle|Unix,Linux,Windows,Mac|8.0|오픈 소스,상용|
# |MariaDB|MariaDB|Unix,Linux,Windows|10.4|오픈 소스|
# |PostgreSQL|PostgreSQL|Unix,Linux,Windows,Mac|11|오픈 소스|
# |Oracle|Oracle|Unix,Linux,Windows|18c|상용 시장 점유율 1위|
# |SQL Server|Microsoft|Windows|2019||
# |DB2|IBM|Unix,Linux,Windows|12|메인프레임 시장 점유율 1위|
# |Access|Microsoft|Windows|2019|PC용|
# |SQLite|SQLite|Android,ios|3|모바일 전용,오픈 소스|

# %% [markdown]
# - DBMS 또는 데이터베이스의 특징
#   1.데이터의 무결성
#     어떤 경로로 들어오든 오류가 있어서는 안 됨
#   2.데이터의 독립성
#     크기 변경, 저장소 변경을 해도 기존에 작성된 응용 프로그램은 영향을 받지 않아야 함
#   3.보안
#     아무나 접근할 수 있는 것이 아니라 소유한 사람이나 허락을 받은 사람만 가능
#   4.데이터 중복의 최소화
#     동일한 데이터가 여러 개 중복되어 저장되는 것을 방지
#   5.응용 프로그램 제작 및 수정이 쉬워짐
#     통일된 방식으로 응용 프로그램 작성이 가능해지고, 유지보수 또한 쉬워짐
#   6.데이터의 안정성 향상
#     데이터가 깨지는 문제가 발생할 경우에 원상으로 복원, 복구라는 방법이 명확

# %% [markdown]
# ### 1.1.2데이터베이스의 발전
# ---

# %% [markdown]
# - 오프라인으로 관리
# - 파일시스템의 사용
# - 데이터베이스 관리시스템

# %% [markdown]
# ### 1.1.3DBMS 분류
# ---

# %% [markdown]
# - 계층형 DBMS

# %% [markdown]
# 처음으로 나온 DBMS 개념,1960년
# 각 계층은 트리 형태를 가지며 1:N관계를 갖는다.
# 접근의 유연성아 부족해서 임의의 검색에는 어려움
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - 망형 DBMS

# %% [markdown]
# 계층형 DBMS의 문제점을 보안하기 위해서 1970년에 시작
# 1:1,1:N,N:M 관계가 지원되어 효과적이고 빠른 데이터 추출이 가능
# 복잡한 내부 포인터를 사용하고 프로그래머가 이 모든 구조를 이해해야만 프로그램의 작성이 가능하다는 단점이 존재

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - 관계형 DBMS

# %% [markdown]
# 1969년 E.F.Codd라는 학자가 수학 모델에 근거해서 고안하면서 시작
# RDBMS의 핵심 개념은 "데이터베이스는 테이블이라 불리는 최소 단위로 구성, 이 테이블은 하나 이상의 열로 구성"

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 1.1.4 SQL개요
# ---

# %% [markdown]
# - DBMS 제작 회사와 독립적이다
#   SQL은 모든 DBMS 제작회사에 공통적으로 공개
# - 다른 시스템으로 이식성이 좋다
#   서버용, 개인용, 휴대용 장비에서 운영되는 DBMS마다 상호 호환성이 뛰어나다
# - 표준이 계속 발전한다
#   자금도 개선된 안이 연구되고 보안되고 있다
# - 대화식 언어이다
# - 분산형 클라이언트/서버 구조이다
#   클라이언트에서 질의하면 서버에서 그 질의를 다운 받아서 처리한 후 다시 클라이언트로 전달하는 구조
