# %% [markdown]
# ## 8.1.3 테이블 압축

# %% [markdown]
# - 실습3

# %% [markdown]
# 테이블의 압축 기능 확인

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 8.1.4 임시 테이블

# %% [markdown]
# - 실습4
